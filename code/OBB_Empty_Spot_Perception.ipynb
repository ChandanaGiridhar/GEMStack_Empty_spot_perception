# %%
import matplotlib.pyplot as plt
from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/My Drive/empty_spot_detection'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 8.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="7RrUWT9mugKJfBTgiAnq")
project = rf.workspace("emptyspotanatote").project("cs588_proj")
version = project.version(4)
dataset = version.download("yolov8-obb")
# Out:
# /content
# /content/datasets
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.1/74.1 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 21.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
# ...

# %%
import os
from ultralytics import YOLO
model = YOLO("yolov8n-obb.pt")
DATA_DIR = '/content/datasets/CS588_PROJ-4/'
results = model.train(data=os.path.join(DATA_DIR,"data.yaml"), epochs=90)
# Out:
# ...
# 100%|██████████| 6.24M/6.24M [00:00<00:00, 121MB/s]
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !scp -r /content/datasets/runs '/content/gdrive/My Drive/empty_spot_detection/Ver2_obb_twilight/'

# %%
from ultralytics import YOLO

# Load a model

model = YOLO('/content/gdrive/My Drive/empty_spot_detection/obb/runs/obb/train2/weights/last.pt')  # load a custom model

# Predict with the model
# !yolo task = obb mode=predict model ='/content/gdrive/My Drive/empty_spot_detection/obb/runs/obb/train2/weights/best.pt' conf = 0.5 source ='/content/test_images/'

# %%
# !scp -r /content/datasets/runs '/content/gdrive/My Drive/empty_spot_detection/obb/trained'

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model='/content/gdrive/My Drive/empty_spot_detection/obb/runs/obb/train2/weights/last.pt' source='/content/img38.jpg'
# !yolo detect.py --weights '/content/gdrive/My Drive/empty_spot_detection/obb/runs/obb/train2/weights/last.pt' --source '/content/img38.jpg' --conf-thres 0.01 --img 416 --device 0 --agnostic

# %%
# !scp -r /content/datasets/runs '/content/gdrive/My Drive/empty_spot_detection/obb/predict/'

# %%
#Validation results from OBB YOLO
display(Image(filename='/content/gdrive/My Drive/empty_spot_detection/obb/train/val_batch0_pred.jpg'))

# %%
#Validation results from NORMAL YOLO
display(Image(filename='/content/gdrive/My Drive/empty_spot_detection/runs/detect/train/val_batch0_pred.jpg'))
